# %%
from pathlib import Path

import pandas as pd

# %%
entrada_crua = pd.read_csv(Path() / "entrada" / "respostas_ao_formulário.csv")

# %%
simplificação = {
    "Qual a sua idade?": "Idade",
    "Você se identifica como": "Gênero",
    "Qual sua orinetação sexual": "Orientação sexual",
    "Como você se identifica?": "Etnia",
    "Em qual cidade você reside": "Município de residência",
    "De acordo com a resposta anterior, você está morando nessa cidade apenas para estudar?": "Mora apenas para estudar?",
    "Caso tenha respondido sim anteriormente, qual a sua cidade de origem?": "Município de origem"
}

# %%
entrada_crua.iloc[:20, :20]
# Out:
#    Carimbo de data/hora                 Endereço de e-mail  Qual a sua idade?  \
# 0   09/02/2021 20:20:56                                NaN                 20
# 1   09/02/2021 20:56:28                                NaN                 22
# 2   10/02/2021 18:36:48           bismarqueleao0@gmail.com                 19
# 3   10/02/2021 18:40:42       vanessa.guirra@easyjr.com.br                 23
# 4   10/02/2021 18:44:16            adrielyds29@hotmail.com                 20
# 5   10/02/2021 18:56:27           ruth19coldplay@gmail.com                 22
# 6   10/02/2021 19:04:11             jeantoscan@hotmail.com                 20
# 7   10/02/2021 19:06:52     nathalia.tamara@souunit.com.br                 25
# 8   10/02/2021 19:06:54      producao.silveira@outlook.com                 20
# 9   10/02/2021 19:10:31      gleyce@quimtecconsultoria.com                 22
# 10  10/02/2021 19:12:09  francisco.mmenezes@souunit.com.br                 20
# ...

# %%
entrada_crua["Qual a sua EJ?"][1]
# Out:
# 'PHYSICS JR'
